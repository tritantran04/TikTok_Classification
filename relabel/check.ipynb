# %%
import pandas as pd

path_storage = pd.read_csv('/Users/nnam/Documents/Workspace/university/mguard/TikTok_Classification/datasets/dataset_with_relative_path.csv')
path_storage.head()
# Out:
#                                           video_path  \
# 0  tikharm-dataset/train/Adult Content/jaypark_fo...
# 1  tikharm-dataset/train/Adult Content/1life.anth...
# 2  tikharm-dataset/train/Adult Content/loungebarv...
# 3  tikharm-dataset/train/Adult Content/phangphong...
# 4  tikharm-dataset/train/Adult Content/girl_xinh....
#
#                                    video_name     class_name original_dir  \
# 0      jaypark_foryou_7339639860354911493.mp4  Adult Content        train
# 1  1life.anthonyblane_7368846422709521671.mp4  Adult Content        train
# 2        loungebarvip_7252268249243454725.mp4  Adult Content        train
# 3       phangphong111_7287936860796620039.mp4  Adult Content        train
# 4      girl_xinh.sexy_7298717939052711170.mp4  Adult Content        train
#
#    split ocr_text                                         audio_text  \
# 0  train      NaN                                                NaN
# 1  train      NaN         Cảm ơn các bạn đã theo dõi và hẹn gặp lại.
# 2  train      NaN  Hey, it's a time. Hey, can you be alright? Hey...
# 3  train      NaN                                                You
# 4  train      NaN                                         Thank you.
#
#                                        combined_text processing_status  \
# 0                                                NaN         completed
# 1  AUDIO: Cảm ơn các bạn đã theo dõi và hẹn gặp lại.         completed
# 2  AUDIO: Hey, it's a time. Hey, can you be alrig...         completed
# 3                                         AUDIO: You         completed
# 4                                  AUDIO: Thank you.         completed
#
#    error_message                                         audio_path
# 0            NaN      audios/jaypark_foryou_7339639860354911493.mp3
# 1            NaN  audios/1life.anthonyblane_7368846422709521671.mp3
# 2            NaN        audios/loungebarvip_7252268249243454725.mp3
# 3            NaN       audios/phangphong111_7287936860796620039.mp3
# 4            NaN      audios/girl_xinh.sexy_7298717939052711170.mp3

# %% [markdown]
# **Check is there any problems in relabling**

# %%
import os 
import json
mapping_file = {}
# Compare the paths in path_storage['video_path'] to the relabeled paths
label_list = list(path_storage['class_name'].unique())
for idx, sample in path_storage.iterrows():
    label = sample['class_name']
    real_path = f"../datasets/{sample['video_path']}"
    if not os.path.exists(real_path):
        print(f'The path {real_path} is false')
        
        # Check is it moved into another folder
        for l in label_list:
            if l != label:
                check_path = "/".join(real_path.split('/')[:-2]) + "/" + str(l) + "/" + sample['video_name']
                if os.path.exists(check_path):
                    print(f"!!! It is moved to  {check_path}!!!")
                    if mapping_file.get(real_path, None):
                        print('This video exists in more than one folder')
                    mapping_file[sample['video_path']] = '/'.join(check_path.split('/')[2:])
                    
with open('relabel.json', 'w', encoding='utf-8') as f:
    json.dump(mapping_file, f, ensure_ascii=False, indent=4)
# Out:
# The path ../datasets/tikharm-dataset/train/Harmful Content/_the_pumpkin_king__7049465712821161262.mp4 is false
# !!! It is moved to  ../datasets/tikharm-dataset/train/Suicide/_the_pumpkin_king__7049465712821161262.mp4!!!
# The path ../datasets/tikharm-dataset/train/Harmful Content/_.ziakyra.__7177802081238027566.mp4 is false
# !!! It is moved to  ../datasets/tikharm-dataset/train/Suicide/_.ziakyra.__7177802081238027566.mp4!!!
